# %% [markdown]
# # Web Scraping Assignment

# %% [markdown]
# In all the following questions, you have to use BeautifulSoup to scrape different websites and collect data as per
# the requirement of the question.

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %% [markdown]
# 1) Write a python program to display IMDB’s Top rated 100 Indian movies’ data
# https://www.imdb.com/list/ls056092300/ (i.e. name, rating, year ofrelease) and make data frame.

# %%
def get_100_movies(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.content, 'html.parser')
    titles=[]
    years=[]
    ratings=[]
    for i in soup.find_all('h3', class_='lister-item-header'):
        titles.append(i.find('a').text.strip())
    for i in soup.find_all('span', class_='lister-item-year'):
        year_text=i.text.strip()
        year = re.search(r'\d{4}', year_text).group()
        years.append(year)
    ratings=[]
    for i in soup.find_all('div', class_='ipl-rating-star small'):
        rating = i.find('span', class_="ipl-rating-star__rating").text.strip()
        ratings.append(rating)
    df=pd.DataFrame({'Name':titles,'Rating':ratings,'Year of Release':years})
    return df

imdb_url = 'https://www.imdb.com/list/ls056092300/'
get_100_movies(imdb_url)
# Out:
#                                  Name Rating Year of Release
# 0                     Ship of Theseus      8            2012
# 1                              Iruvar    8.4            1997
# 2                     Kaagaz Ke Phool    7.8            1959
# 3   Lagaan: Once Upon a Time in India    8.1            2001
# 4                     Pather Panchali    8.2            1955
# ..                                ...    ...             ...
# 95                        Apur Sansar    8.4            1959
# 96                        Kanchivaram    8.2            2008
# 97                    Monsoon Wedding    7.3            2001
# 98                              Black    8.1            2005
# 99                            Deewaar      8            1975
#
# [100 rows x 3 columns]

# %% [markdown]
# 2) Write a python program to scrape product name, price and discounts from
# https://www.meesho.com/bags-ladies/pl/3jo?page=1

# %%
def meesho_products(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.content)
    names=[]
    prices=[]
    discounts=[]
    for i in soup.find_all('div', class_='product-title'):
        names.append(i.find('a').text.strip())
    return names

url="https://peachmode.com/search?q=bags"
meesho_products(url)
# Out:
# ['${ item.title }$']

# %% [markdown]
# 3) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

# %% [markdown]
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
def odi_teams(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.content, 'html.parser')
    teams=[]
    matches=[]
    points=[]
    ratings=[]
    for i in soup.find_all('span',class_='si-fname si-text'):
        teams.append(i.text)
    for i in soup.find_all('div', class_='si-table-data si-matches'):
        matches.append(i.find('span').text.strip())

    return matches
url="https://www.icc-cricket.com/rankings/team-rankings/mens/odi"
odi_teams(url)
# Out:
# []

# %% [markdown]
# Please visit https://www.cnbc.com/world/?region=world and scrap-
#
# a) headings
#
# b) date
#
# c) News link

# %%
def scrape_cnbc_news(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    headings = []
    dates = []
    news_links = []
    for i in soup.find_all('div', class_="RiverHeadline-headline RiverHeadline-hasThumbnail"):
        headings.append(i.find('a').text.strip())
    for i in soup.find_all('div', class_="RiverHeadline-headline RiverHeadline-hasThumbnail"):
        news_links.append((i.find('a'))['href'])
    df=pd.DataFrame({'Headline':headings, 'News link':news_links})
    return df


url = "https://www.cnbc.com/world/?region=world"
scrape_cnbc_news(url)
# Out:
#                                              Headline  \
# 0   Ship sunk by Houthis threatens Red Sea environ...
# 1
# 2   Short positions in China stocks shrink after r...
# 3   Nasdaq surges more than 1% to take out 2021 re...
# 4   Trump wins caucuses in Missouri and Idaho and ...
# 5   India approves chip plants with over $15 billi...
# 6
# 7   Ukraine's losses on the battlefield could make...
# 8   India’s Byju’s lost more than $20 billion in v...
# 9   Iran vote turnout hits historic low amid disco...
# 10  Why China, Japan and the Fed are shaking up th...
# 11  The Toronto Stock Exchange’s parent company ju...
# 12  Tesla rolls out new incentives in China as pri...
# 13  Lawyers seek nearly $6 billion in Tesla stock ...
# 14  China calls on foreign businesses to share the...
# 15  Here's what tech giants are betting on — from ...
# 16  Yum China CEO says consumers are growing more ...
# 17  Britain to lead 2024 European real estate boom...
# 18  WTO fails on major reforms, extends digital ta...
# 19  Navalny's funeral in pictures: Mourners gather...
#
#                                             News link
# 0   https://www.cnbc.com/2024/03/03/ship-sunk-by-h...
# 1                                               /pro/
# 2   https://www.cnbc.com/2024/03/03/short-position...
# 3   https://www.cnbc.com/2024/02/29/stock-market-t...
# 4   https://www.cnbc.com/2024/03/02/trump-wins-the...
# 5   https://www.cnbc.com/2024/03/01/india-boosts-c...
# 6                                               /pro/
# 7   https://www.cnbc.com/2024/03/01/ukraines-losse...
# 8   https://www.cnbc.com/2024/03/01/the-rise-and-f...
# 9   https://www.cnbc.com/2024/03/03/iran-vote-turn...
# 10  https://www.cnbc.com/2024/02/29/why-china-japa...
# 11  https://www.cnbc.com/2024/03/02/one-of-the-mos...
# 12  https://www.cnbc.com/2024/03/02/tesla-rolls-ou...
# 13  https://www.cnbc.com/2024/03/02/lawyers-seek-n...
# 14  https://www.cnbc.com/2024/03/01/china-calls-on...
# 15  https://www.cnbc.com/2024/03/01/latest-tech-ga...
# 16  https://www.cnbc.com/2024/03/01/yum-china-ceo-...
# 17  https://www.cnbc.com/2024/03/01/uk-europe-real...
# 18  https://www.cnbc.com/2024/03/02/wto-fails-on-m...
# 19  https://www.cnbc.com/2024/03/01/navalnys-funer...

# %% [markdown]
# Please visit https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/ and scrap-
#
# a) Paper title
#
# b) date
#
# c) Author

# %%
def scrape_downloaded_articles(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.content, 'html.parser')
    paper_titles=[]
    dates=[]
    authors=[]
    for i in soup.find_all('h2',class_='h5 article-title'):
        paper_titles.append(i.find('a').text.strip())
    for i in soup.find_all('p', class_='article-date'):
        dates.append(i.text.strip())
    for i in soup.find_all('p', class_='article-authors'):
        authors.append(i.text.strip())
    df=pd.DataFrame({'Paper title':paper_titles,'Date':dates,'Author':authors})
    return df

url = "https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/"
scrape_downloaded_articles(url)
# Out:
#                                           Paper title            Date  \
# 0   Implementation of artificial intelligence in a...            2020
# 1               Review of agricultural IoT technology            2022
# 2   A comprehensive review on automation in agricu...       June 2019
# 3   Automation and digitization of agriculture usi...            2021
# 4   Applications of electronic nose (e-nose) and e...            2020
# 5             Fruit ripeness classification: A survey      March 2023
# 6   A review of imaging techniques for plant disea...            2020
# 7   Deep learning based computer vision approaches...            2022
# 8   Comparison of CNN-based deep learning architec...  September 2023
# 9   Transfer Learning for Multi-Crop Leaf Disease ...            2022
# 10  Plant disease detection using hybrid model bas...            2021
# 11  Machine learning in nutrient management: A review  September 2023
# 12  DeepRice: A deep learning and deep feature bas...      March 2024
# 13  How artificial intelligence uses to achieve th...       June 2023
# 14  Machine learning for weed–plant discrimination...   December 2023
# 15  Examining the interplay between artificial int...            2022
# 16  Deep convolutional neural network models for w...            2022
# 17  A systematic review of machine learning techni...            2022
# 18  A review on computer vision systems in monitor...            2020
# 19  Crop diagnostic system: A robust disease detec...   December 2023
# 20  Artificial cognition for applications in smart...            2020
# 21  Explainable artificial intelligence and interp...            2022
# 22         Blockchain: A new safeguard for agri-foods            2020
# 23  Study on body temperature detection of pig bas...      March 2019
# 24  Vision Intelligence for Smart Sheep Farming: A...      March 2024
#
#                                                Author
# 0   Tanha Talaviya |  Dhara Shah |  Nivedita Patel...
# 1          Jinyuan Xu |  Baoxing Gu |  Guangzhao Tian
# 2   Kirtan Jha |  Aalap Doshi |  Poojan Patel |  M...
# 3                            A. Subeesh |  C.R. Mehta
# 4                               Juzhong Tan |  Jie Xu
# 5   Matteo Rizzo |  Matteo Marcuzzo |  Alessandro ...
# 6        Vijai Singh |  Namita Sharma |  Shikha Singh
# 7   V.G. Dhanya |  A. Subeesh |  N.L. Kushwaha |  ...
# 8   Md Taimur Ahad |  Yan Li |  Bo Song |  Touhid ...
# 9              Ananda S. Paymode |  Vandana B. Malode
# 10                         Punam Bedi |  Pushkar Gole
# 11  Oumnia Ennaji |  Leonardus Vergütz |  Achraf E...
# 12  P. Isaac Ritharson |  Kumudha Raimond |  X. An...
# 13            Vilani Sachithra |  L.D.C.S. Subhashini
# 14  Filbert H. Juwono |  W.K. Wong |  Seema Verma ...
# 15  Abderahman Rejeb |  Karim Rejeb |  Suhaiza Zai...
# 16  A. Subeesh |  S. Bhole |  K. Singh |  N.S. Cha...
# 17  Md Ekramul Hossain |  Muhammad Ashad Kabir |  ...
# 18  Cedric Okinda |  Innocent Nyalala |  Tchalla K...
# 19               R. Abbasi |  P. Martinez |  R. Ahmad
# 20  Misbah Pathan |  Nivedita Patel |  Hiteshri Ya...
# 21                                       Masahiro Ryo
# 22    Jie Xu |  Shuang Guo |  David Xie |  Yaxuan Yan
# 23          Zaiqin Zhang |  Hang Zhang |  Tonghai Liu
# 24  Galib Muhammad Shahriar Himel |  Md. Masudul I...

# %% [markdown]
# Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar.

# %%
def nobrokerurl(url):
    page=requests.get(url)
    soup=BeautifulSoup(page.content,'html.parser')
    houses=[]
    locations=[]
    emis=[]
    for i in soup.find_all('div',class_='text-16 text-my-booking-color whitespace-nowrap overflow-hidden overflow-ellipsis'):
        houses.append(i.text.strip())
    
    return houses
url='https://www.nobroker.in/'
nobrokerurl(url)
# Out:
# []
